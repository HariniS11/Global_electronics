# %%
import pandas as pd
path = r'C:\Users\ADMIN\Desktop\Dataspark\Customers.csv'
df_customers = pd.read_csv('Customers.csv')
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Dušková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df_customers.describe()
# Out:
#         CustomerKey
# count  1.526600e+04
# mean   1.060508e+06
# std    6.127097e+05
# min    3.010000e+02
# 25%    5.140335e+05
# 50%    1.079244e+06
# 75%    1.593980e+06
# max    2.099937e+06

# %%
df_customers.describe(include='object') #duplicates find
# Out:
#        Gender        Name     City State Code       State Zip Code  \
# count   15266       15266    15266      15256       15266    15266
# unique      2       15118     8258        467         512     9505
# top      Male  John Smith  Toronto         CA  California    90017
# freq     7748           4      204        740         715       70
#
#               Country      Continent   Birthday
# count           15266          15266      15266
# unique              8              3      11270
# top     United States  North America  6/12/1989
# freq             6828           8381          5

# %%
df_customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
df_customers.isnull().sum()/df_customers.shape[0]*100
# Out:
# CustomerKey    0.000000
# Gender         0.000000
# Name           0.000000
# City           0.000000
# State Code     0.065505
# State          0.000000
# Zip Code       0.000000
# Country        0.000000
# Continent      0.000000
# Birthday       0.000000
# dtype: float64

# %%
df_customers.duplicated(subset=['Name']).value_counts()
# Out:
# False    15118
# True       148
# Name: count, dtype: int64

# %%
df_customers_update = df_customers.drop('State Code',axis=1)
df_customers_updated = df_customers_update

# %%
df_customers_updated
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Dušková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# ...

# %%
# import pandas as pd
# from datetime import datetime


# df_customers_update['Birthday'] = pd.to_datetime(df_customers_update['Birthday'], format='%m/%d/%Y')
# def calculate_age(birthdate):
#     today = datetime.today()
#     return today.year - birthdate.year - ((today.month, today.day) < (birthdate.month, birthdate.day))

# # Add age column
# df_customers_update['Age'] = df_customers_update['Birthday'].apply(calculate_age)

# # Print the updated DataFrame
# print(df_customers_update)

# %%
df_customers_update_1 = df_customers_update
df_customers_update_1
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Dušková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday  \
# 0        South Australia     5523      Australia      Australia 1939-07-03
# ...

# %%
df_customers_update_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State        15266 non-null  object
#  5   Zip Code     15266 non-null  object
#  6   Country      15266 non-null  object
#  7   Continent    15266 non-null  object
#  8   Birthday     15266 non-null  datetime64[ns]
#  9   Age          15266 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
df_customers_update_1.describe(include = 'object')
# Out:
#        Gender        Name     City       State Zip Code        Country  \
# count   15266       15266    15266       15266    15266          15266
# unique      2       15118     8258         512     9505              8
# top      Male  John Smith  Toronto  California    90017  United States
# freq     7748           4      204         715       70           6828
#
#             Continent
# count           15266
# unique              3
# top     North America
# freq             8381

# %%
# result = df.drop_duplicates(subset=['Name'])
#df.drop_duplicates(inplace=True)

# %%
df_Exchange_Rates = pd.read_csv('Exchange_Rates.csv')
df_Exchange_Rates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_Exchange_Rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
import pandas as pd
df_Sales = pd.read_csv('Sales.csv')
df_Sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
# df_sales_update = df_Sales.drop('Line Item',axis = 1)

# %%
df_sales_updated =  df_Sales.drop('Delivery Date',axis = 1)

# %%
df_sales_updated
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1   1/1/2016       265598        10        1304
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1  2/20/2021      1216913        43         632
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
df_sales_updated['Order Date'] = pd.to_datetime(df_sales_updated['Order Date'])

# %%
df_sales_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  datetime64[ns]
#  3   CustomerKey    62884 non-null  int64
#  4   StoreKey       62884 non-null  int64
#  5   ProductKey     62884 non-null  int64
#  6   Quantity       62884 non-null  int64
#  7   Currency Code  62884 non-null  object
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 3.8+ MB

# %%
df_stores = pd.read_csv('Stores.csv')
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df_stores_updated = df_stores.drop(df_stores.index[66])

# %%
df_stores_updated
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 61        62  United States                  South Dakota         1120.0
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df_stores_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       66 non-null     int64
#  1   Country        66 non-null     object
#  2   State          66 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      66 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df_stores_updated['Open Date'] = pd.to_datetime(df_stores_updated['Open Date'])

# %%
df_stores_updated.describe()
# Out:
#         StoreKey  Square Meters                      Open Date
# count  66.000000      66.000000                             66
# mean   33.500000    1402.196970  2011-07-02 04:43:38.181818112
# min     1.000000     245.000000            2005-03-04 00:00:00
# 25%    17.250000    1108.750000            2009-06-03 00:00:00
# 50%    33.500000    1347.500000            2011-03-18 12:00:00
# 75%    49.750000    2000.000000            2013-06-07 00:00:00
# max    66.000000    2105.000000            2019-03-05 00:00:00
# std    19.196354     576.404058                            NaN

# %%
df_products = pd.read_csv('Products.csv')
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
########### EXPLORATORY DATA ANALYSIS #############

# %%
df_customers_update_1
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Dušková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday  \
# 0        South Australia     5523      Australia      Australia 1939-07-03
# ...

# %%
df_customers_update_1.describe()
# Out:
#         CustomerKey                       Birthday           Age
# count  1.526600e+04                          15266  15266.000000
# mean   1.060508e+06  1968-09-20 13:51:07.050962920     55.727106
# min    3.010000e+02            1935-02-03 00:00:00     22.000000
# 25%    5.140335e+05            1952-02-10 06:00:00     39.000000
# 50%    1.079244e+06            1968-07-25 12:00:00     56.000000
# 75%    1.593980e+06            1985-06-09 18:00:00     72.000000
# max    2.099937e+06            2002-02-18 00:00:00     89.000000
# std    6.127097e+05                            NaN     19.320642

# %%
 #15266
df_customers_update_1.describe(include = 'object')
df_customers_update_1.duplicated(subset=['Name']).value_counts()
df_customers_update_1[df_customers_update_1['Name']=='John Smith']
# Out:
#        CustomerKey Gender        Name         City          State Zip Code  \
# 1861        255089   Male  John Smith       Ottawa        Ontario  K1H 7Z1
# 8934       1264890   Male  John Smith    New Haven    Connecticut     6511
# 9934       1398234   Male  John Smith  Los Angeles     California    90017
# 11621      1616770   Male  John Smith  Springfield  Massachusetts     1109
#
#              Country      Continent   Birthday  Age
# 1861          Canada  North America 1956-08-03   68
# 8934   United States  North America 1965-04-07   59
# 9934   United States  North America 1962-04-19   62
# 11621  United States  North America 1981-04-24   43

# %%
                             ####### SALES DATA ANALYSIS ########
df_sales_updated
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
df_sales_updated.describe()
# Out:
#        Order Number     Line Item                     Order Date  \
# count  6.288400e+04  62884.000000                          62884
# mean   1.430905e+06      2.164207  2018-11-30 21:21:56.939126016
# min    3.660000e+05      1.000000            2016-01-01 00:00:00
# 25%    1.121017e+06      1.000000            2018-01-25 00:00:00
# 50%    1.498016e+06      2.000000            2019-02-06 00:00:00
# 75%    1.788010e+06      3.000000            2019-11-23 00:00:00
# max    2.243032e+06      7.000000            2021-02-20 00:00:00
# std    4.532963e+05      1.365170                            NaN
#
#         CustomerKey      StoreKey    ProductKey      Quantity
# count  6.288400e+04  62884.000000  62884.000000  62884.000000
# mean   1.180797e+06     31.802144   1125.859344      3.144790
# min    3.010000e+02      0.000000      1.000000      1.000000
# 25%    6.808580e+05      8.000000    437.000000      1.000000
# 50%    1.261200e+06     37.000000   1358.000000      2.000000
# ...

# %%
df_customer_analysis = pd.merge(df_customers_update_1, df_sales_updated, on='CustomerKey', how='inner') 

df_customer_analysis
# Out:
#        CustomerKey  Gender              Name                 City  \
# 0              301  Female     Lilly Harding       WANDEARAH EAST
# 1              325  Female      Madison Hull           MOUNT BUDD
# 2              325  Female      Madison Hull           MOUNT BUDD
# 3              325  Female      Madison Hull           MOUNT BUDD
# 4              325  Female      Madison Hull           MOUNT BUDD
# ...            ...     ...               ...                  ...
# 62879      2099937    Male  Zygmunt Kaminski  Bloomfield Township
# 62880      2099937    Male  Zygmunt Kaminski  Bloomfield Township
# 62881      2099937    Male  Zygmunt Kaminski  Bloomfield Township
# 62882      2099937    Male  Zygmunt Kaminski  Bloomfield Township
# 62883      2099937    Male  Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday  \
# 0        South Australia     5523      Australia      Australia 1939-07-03
# ...

# %%
df_customer_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerKey    62884 non-null  int64
#  1   Gender         62884 non-null  object
#  2   Name           62884 non-null  object
#  3   City           62884 non-null  object
#  4   State          62884 non-null  object
#  5   Zip Code       62884 non-null  object
#  6   Country        62884 non-null  object
#  7   Continent      62884 non-null  object
#  8   Birthday       62884 non-null  datetime64[ns]
#  9   Age            62884 non-null  int64
#  10  Order Number   62884 non-null  int64
#  11  Line Item      62884 non-null  int64
#  12  Order Date     62884 non-null  datetime64[ns]
#  13  StoreKey       62884 non-null  int64
#  14  ProductKey     62884 non-null  int64
#  15  Quantity       62884 non-null  int64
#  16  Currency Code  62884 non-null  object
# ...

# %%
df_customer_analysis.describe()
df_customer_analysis.duplicated(subset = ['CustomerKey']).sum()
# Out:
# np.int64(50997)

# %%
df_customer_analysis.describe(include = 'object')
# Out:
#        Gender              Name     City       State Zip Code        Country  \
# count   62884             62884    62884       62884    62884          62884
# unique      2             11783     6570         491     7771              8
# top      Male  Gaspare Trevisan  Toronto  California    90017  United States
# freq    31804                36      683        3629      317          33767
#
#             Continent Currency Code
# count           62884         62884
# unique              3             5
# top     North America           USD
# freq            39182         33767

# %%
# Seaborn helps to visualize the statistical relationships, to understand how variables in a dataset are related to
#  one another and how that relationship is dependent on other variables, we perform statistical analysis.

# %%
#df_customers_updated,df_sales_updated,df_stores_updated,df_products,df_Exchange_Rates

# %%
df_customers_updated['Birthday'] = pd.to_datetime(df_customers_updated['Birthday'])

# %%
df_customers_updated
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Dušková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday
# 0        South Australia     5523      Australia      Australia 1939-07-03
# ...

# %%
import pymysql 
import mysql.connector

connection = pymysql.connect(
     host='localhost',
     user = 'root',
     password='12345',
     database='dataspark'
    )
print(connection)
cursor = connection.cursor()
print(cursor)

# %%
#Table creation

table_creation = """create table customers(
                      CustomerKey int primary key,
                      Gender varchar(100),
                      Name varchar(200),
                      City varchar(200),
                      State varchar(200),
                      `Zip Code` varchar(200),
                      Country varchar(200),
                      Continent varchar(200),
                      Birthday date
                      )"""
cursor.execute(table_creation)
connection.commit()

# %%
insert_sql = """insert into customers(CustomerKey,
                                       Gender,
                                       Name,
                                       City,
                                       State,
                                       `Zip code`,
                                       Country,
                                       Continent,
                                       Birthday)
                                    Values(%s, %s, %s, %s, %s , %s, %s, %s, %s)"""

values = [tuple(row) for row in df_customers_updated.values]

try:
   cursor = connection.cursor()
   batchsize = 1000
   for i in range(0,len(values),batchsize):
      batch_values = values[i:i+batchsize]
      cursor.executemany(insert_sql,batch_values)
      connection.commit()
   print('successfully inserted')   
except: 
   print('some error occur')

# %%
df_sales_updated['Order Date'] = pd.to_datetime(df_sales_updated['Order Date'])

# %%
connection.close()

# %%
# sales table
sales_table = """create table sales(
                   `Order Number` int,
                   `Line Item` int,
                   `Order date` date,
                   CustomerKey int,
                   StoreKey int,
                   ProductKey int,
                   Quantity int,
                   `Currency Code` varchar(100),
                   foreign key(CustomerKey) references customers(CustomerKey)
                   )"""
cursor.execute(sales_table)
connection.commit()
print('table created')
# Out:
# table created

# %%
import traceback
import pymysql
import mysql.connector


insert_sales = """insert into sales(
                   `Order Number`,
                   `Line Item`,
                   `Order date`,
                   CustomerKey,
                   StoreKey,
                   ProductKey,
                   Quantity,
                   `Currency Code`)
                 values(%s, %s, %s, %s, %s, %s, %s, %s)"""

sales_values = [tuple(row) for row in df_sales_updated.values]

try:
    cursor = connection.cursor()
    batch_size = 1000
    for i in range(0,len(sales_values),batch_size):
        batch_values = sales_values[i:i+batch_size]
        cursor.executemany(insert_sales , batch_values)
        connection.commit()
    print('successfully inserted')    

except:
  print('error') 
  traceback.print_exc()
# Out:
# successfully inserted

# %%
df_sales_updated.shape[0]
# Out:
# 62884

# %%
#stores table creation

table_creation = """create table stores(
                      StoreKey int not null primary key,
                      Country varchar(200),
                      State varchar(200),
                      `Square Meters` float,
                      `Open Date` date
                      )"""
cursor.execute(table_creation)
connection.commit()

# %%
#stores table

import traceback
import pymysql
import mysql.connector


insert_stores = """insert into stores(
                   StoreKey,
                   Country,
                   State,
                   `Square Meters`,
                   `Open Date`)
                 values(%s, %s, %s, %s, %s)"""

stores_values = [tuple(row) for row in df_stores_updated.values]

cursor.executemany(insert_stores,stores_values)
connection.commit()

# %%
# print(df_products['Unit Cost USD'].unique())
# print(df_products[df_products['Unit Cost USD'].isna()])

df_products['Unit Cost USD'] = (
    df_products['Unit Cost USD']
    .str.replace(r'\$', '', regex=True)  
    .str.replace(',', '', regex=False)  
    .str.strip()                       
)

# Convert to float
df_products['Unit Cost USD'] = df_products['Unit Cost USD'].astype(float)

# %%
df_products['Unit Price USD'] = (
    df_products['Unit Price USD']
    .str.replace(r'\$', '', regex=True) 
    .str.replace(',', '', regex=False)  
    .str.strip()                        
)

# Convert to float
df_products['Unit Price USD'] = df_products['Unit Price USD'].astype(float)

# %%
#stores table creation

table_creation = """create table products(
                    ProductKey int primary key,
                    `Product Name` varchar(250),
                    Brand varchar(250),
                    Color varchar(250),
                    `Unit Cost USD` float,
                    `Unit Price USD` float,
                    `SubcategoryKey` int,
                     Subcategory varchar(250),
                     CategoryKey int,
                     Category varchar(250)
                      )"""
cursor.execute(table_creation)
connection.commit()

# %%
#stores table

import traceback
import pymysql
import mysql.connector


insert_products = """insert into products(
                   ProductKey,
                    `Product Name`,
                    Brand,
                    Color,
                    `Unit Cost USD`,
                    `Unit Price USD`,
                    `SubcategoryKey`,
                     Subcategory,
                     CategoryKey,
                     Category)
                 values(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""

products_values = [tuple(row) for row in df_products.values]

cursor.executemany(insert_products,products_values)
connection.commit()

# %%
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
df_Exchange_Rates['Date'] = pd.to_datetime(df_Exchange_Rates['Date'])

# %%
#         EXCHANGE RATES table creation

table_creation = """create table exchange_rates(
                    Date date,
                    Currency varchar(250),
                    Exchange float
                      )"""
cursor.execute(table_creation)
connection.commit()

# %%
import traceback
import pymysql
import mysql.connector


insert_exchange_rates = """insert into exchange_rates(
                  Date,
                  Currency,
                  Exchange)
                 values(%s, %s, %s)"""

exchange_rates_values = [tuple(row) for row in df_Exchange_Rates.values]

try:
    cursor = connection.cursor()
    batch_size = 1000
    for i in range(0,len(exchange_rates_values),batch_size):
        batch_values = exchange_rates_values[i:i+batch_size]
        cursor.executemany(insert_exchange_rates , batch_values)
        connection.commit()
    print('successfully inserted')    

except:
  print('error') 
  traceback.print_exc()
# Out:
# successfully inserted

# %%
df_Exchange_Rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB
